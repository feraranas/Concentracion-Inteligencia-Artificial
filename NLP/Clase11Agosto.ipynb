# %% [markdown]
# # Exercise:
# ### 1. Choose a sound in .wav
# ### 2. Plot the wavesound
# ### 3. Reduce the sound duration in seconds to half the time
# ### 4. Calculate the highest and lowest value of the wave amplitude
# ### 5. Choose a new sound or song and plot both wave sounds in the same display to compare them in two different colors and transparency
#
# #### Ref: https://librosa.org/doc/latest/index.html

# %%
# !pip install librosa
# !pip install -U matplotlib

# %%
import librosa
import soundfile as sf
import numpy as np
from IPython.display import Audio

# %% [markdown]
# ### 1. Choose a sound in .wav

# %%
# Loading the audio as wave form 'y',
# Storing the sampling rate as 'sr'
y, sr = librosa.load('bear_growl_y.wav')

# %%
# Why is it 99,962? What does it mean to a wave form to be represented as an array?
y.mean
# Out:
# <function ndarray.mean>

# %% [markdown]
# ### 2. Plot the wavesound

# %%
import librosa.display
import matplotlib.pyplot as plt

plt.figure(figsize=(12,4))
librosa.display.waveshow(y, sr = sr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 6
#       4 plt.figure(figsize=(12,4))
#       5 librosa.display.waveshow(y, sr = sr)
# ----> 6 plt.show()
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# ...

# %% [markdown]
# ### 3. Reduce the sound duration in seconds to half the time

# %%
# Calculate the new target sampling rate to reduce duration by half
new_sr = int(sr * 2)

# %%
# Resample the audio to the new sampling rate
resampled_audio = librosa.resample(y, orig_sr=sr, target_sr=new_sr)

# %%
# Save the resampled audio to a new file
output_file = "resampled_bear_audio.wav"
sf.write(output_file, resampled_audio, new_sr)

# %%
# Another strategy is giving another parameter to librosa.load() function
yHalf = librosa.load('bear_growl_y.wav', duration=2.5)
yHalf = np.array(yHalf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Another strategy is giving another parameter to librosa.load() function
#       2 yHalf = librosa.load('bear_growl_y.wav', duration=2.5)
# ----> 3 yHalf = np.array(yHalf)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %% [markdown]
# ### 4. Calculate the highest and lowest value of the wave amplitude

# %%
y, sr = librosa.load('resampled_bear_audio.wav')

# Calculate the highest and lowest values of the wave amplitude
max_amplitude = np.max(y)
min_amplitude = np.min(y)

print("Highest amplitude:", max_amplitude)
print("Lowest amplitude:", min_amplitude)
# Out:
# Highest amplitude: 0.99696994
# Lowest amplitude: -1.0010381

# %% [markdown]
# ### 5. Choose a new sound or song and plot both wave sounds in the same display to compare them in two different colors and transparency

# %%
# New sound: included audio example
filename = librosa.example('nutcracker')

y2, sr2 = librosa.load(filename)

plt.figure(figsize=(12,4))
librosa.display.waveshow(y, sr = sr)
librosa.display.waveshow(y2, sr = sr2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 9
#       7 librosa.display.waveshow(y, sr = sr)
#       8 librosa.display.waveshow(y2, sr = sr2)
# ----> 9 plt.show()
#      11 combined = Audio(y + y2, rate=sr)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# ...

# %%
combined = Audio(y + y2[:99962], rate=sr)

# %%
combined
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
