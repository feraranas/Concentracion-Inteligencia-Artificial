# %% [markdown]
# Clase 8 Agosto - Diego López

# %%
import math
x = -(1/30*math.log(1/30, 2) + 29/30*math.log(29/30, 2))
print(x)

# %%
# Ejercicios
# π = [0.775, 0.116, 0.039, 0.070]
# Real label = [1, 0, 0, 0]
π = 0.775 # is the probability of the image being 1, so
e = 2.71828
ex1 = -1 * (1 * math.log(π, e) + (1 - 1) * math.log(1 - π, e))

# %%
π = 0.116
e = 2.71828
ex2 = -1 * (0 * math.log(π, e) + (1 - 0) * math.log(1 - π, e))

# %%
π = 0.039
e = 2.71828
ex3 = -1 * (0 * math.log(π, e) + (1 - 0) * math.log(1 - π, e))

# %%
π = 0.070
e = 2.71828
ex4 = -1 * (0 * math.log(π, e) + (1 - 0) * math.log(1 - π, e))
