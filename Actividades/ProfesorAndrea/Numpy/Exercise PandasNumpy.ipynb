# %% [markdown]
# #Exercise
#
# Instructions:
#
# 1. Load DataSet as DataFame.
#
# 2. Create DF X_data from columns:"longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","ocean_proximity".
# Create y_data with column "median_house_value"
#
#
# 3. Replace NaN values with mean method
#
# 4. Create a new column called "rooms_per_household" defined as the ratio between the "total_rooms" and "households".
#
# 5. Create a new_column called "bedrooms_per_room" defined as the ratio between "total_bedrooms" and "total_rooms".
#
# 6. Create a new column called "population_per_household" defined as the ratio between "population" and "households".
#
# 7. Asign a int value for every category in the "ocean_proximity":
#
#   "<1H OCEAN" -> 1,
#   "NEAR OCEAN"-> 2,
#   ...
#
# 8.  Transform the X_data with the complete numeric data as a NumPy Array.
#
#
# 9. Apply min-max for all columns except the ocean_proximity column.
#
# $min$_$max$ = $X-min/(max-min)$
# 10. Split in train and test for X_data and y_data with test_ratio = 0.2

# %% [markdown]
# # Step 1. Load Data

# %%
import pandas as pd
import numpy as np

# %%
#Write your code
#Load the housing.csv file
# Out:
#      <input type="file" id="files-afc06f06-6492-4455-9297-00cbf0fa6f30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-afc06f06-6492-4455-9297-00cbf0fa6f30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Write your code here
df =

# %%
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %% [markdown]
# # Step 2. Create X_data

# %%
# Create data set with the correct columns
#Write your code here
X_data =

# %%
X_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# #Step 3. Fill Nan values with mean

# %%
#Compute the mean
#Write your code here

mean =

#Fill NaN values, remember inplace = True
#Write your code here
# Out:
# <ipython-input-98-1c4a589e2c7f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_data['total_bedrooms'].fillna(mean,inplace=True)

# %%
X_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# # Step 4,5,6. Creation of new columns

# %%
#Create new columns in X_data
# Write your code here
X_data["rooms_per_household"] =
X_data["bedrooms_per_room"] =
X_data["population_per_household"]=

# %%
X_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 20640 non-null  float64
#  1   latitude                  20640 non-null  float64
#  2   housing_median_age        20640 non-null  float64
#  3   total_rooms               20640 non-null  float64
#  4   total_bedrooms            20640 non-null  float64
#  5   population                20640 non-null  float64
#  6   households                20640 non-null  float64
#  7   median_income             20640 non-null  float64
#  8   ocean_proximity           20640 non-null  object
#  9   rooms_per_household       20640 non-null  float64
#  10  bedrooms_per_room         20640 non-null  float64
#  11  population_per_household  20640 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# # Step 7. Transform to numeric categoritc Data

# %%
X_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
mapping = {'NEAR BAY':1, '<1H OCEAN':2, 'INLAND':3, 'NEAR OCEAN':4, 'ISLAND':5}

# %%
X_data.replace({'ocean_proximity':mapping},inplace=True)

# %%
X_data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  ocean_proximity  \
# 20635       845.0       330.0         1.5603                3
# 20636       356.0       114.0         2.5568                3
# 20637      1007.0       433.0         1.7000                3
# 20638       741.0       349.0         1.8672                3
# 20639      1387.0       530.0         2.3886                3
#
#        rooms_per_household  bedrooms_per_room  population_per_household
# ...

# %% [markdown]
# # Step 8. Transform to NumPy array

# %%
#Convert the numeric data X_data to numpy array
#Write your code
X_array =

# %%
np.shape(X_array)
# Out:
# (20640, 12)

# %%
#Create the numpy array y_array of "median house values" column
#Write your code
y_array =

# %%
np.shape(y_array)
# Out:
# (20640,)

# %% [markdown]
# # Step 8. MinMax transformation

# %%
#Compute the max value per column
#Write your  code here
max_cols =
max_cols
# Out:
# array([-1.14310000e+02,  4.19500000e+01,  5.20000000e+01,  3.93200000e+04,
#         6.44500000e+03,  3.56820000e+04,  6.08200000e+03,  1.50001000e+01,
#         5.00000000e+00,  1.41909091e+02,  1.71153447e+01,  1.24333333e+03])

# %%
#Compute the min value per column
#Write your code here
min_cols =
min_cols
# Out:
# array([-1.24350000e+02,  3.25400000e+01,  1.00000000e+00,  2.00000000e+00,
#         1.00000000e+00,  3.00000000e+00,  1.00000000e+00,  4.99900000e-01,
#         1.00000000e+00,  8.46153846e-01,  1.00000000e-01,  6.92307692e-01])

# %%
#Apply formula for X_array
#Write your code here
min_max_data =

# %% [markdown]
# #Step 9. Return the X_train,y_train, X_test,y_test dataset

# %%
# Make function to split X and y arrays, remember the indexes must be the same for X and y
def split_train_test(X,y,test_ratio):
  shuffled_indices = np.random.permutation(len(X))
  test_set_size = int(len(X) * test_ratio)
  test_indices = shuffled_indices[:test_set_size]
  train_indices = shuffled_indices[test_set_size:]
  #Return X_train,X_test,y_train,y_test
  #Write your code here

# %%
#Call function split_train_test
#Write your code here
X_train,X_test,y_train,y_test =

# %%
np.shape(X_train)
# Out:
# (16512, 12)

# %%
np.shape(y_train)
# Out:
# (16512,)

# %%
np.shape(X_test)
# Out:
# (4128, 12)

# %%
np.shape(y_test)
# Out:
# (4128,)

# %% [markdown]
# # Congratulations, you can prove your dataset in a Machine Learning algorithm!!!
